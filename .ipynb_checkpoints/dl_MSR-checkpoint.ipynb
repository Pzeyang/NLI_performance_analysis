# %% [markdown]
# ## MSR Paraphrase Data: Deep learning

# %%
# import statements
import pandas as pd
import numpy as np
from tqdm import tqdm
from keras.models import Sequential, Model
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import LSTM, GRU
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
from keras.layers import Input, concatenate, dot, Flatten, Reshape, Bidirectional, add
from keras.layers import TimeDistributed, Lambda
from keras.layers import Convolution1D, GlobalMaxPooling1D
from keras.regularizers import l2
from keras.layers import dot, Dot
from keras.activations import softmax
from keras.layers import Permute, subtract, multiply, GlobalAvgPool1D, GlobalMaxPool1D
from keras.callbacks import ModelCheckpoint
from keras import backend as K
from keras.layers.advanced_activations import PReLU
from keras.optimizers import Adadelta
import keras.backend as K
import tensorflow as tf
from keras.layers import Conv1D, MaxPooling1D, Embedding
from keras.preprocessing import sequence, text
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, recall_score, precision_score
import functions.utils as utils
from functions.utils import *
import models.deep_learning as deep_learning
from models.deep_learning import *
from functions.model_evaluation import *
import functions.model_evaluation
from sklearn.model_selection import train_test_split
import csv
# Out:
# Using TensorFlow backend.

# %%
# Loading the training and testing data
train = pd.read_csv(r'Data/msr_paraphrase_train.txt', sep = '\t', quoting=csv.QUOTE_NONE)
test = pd.read_csv(r'Data/msr_paraphrase_test.txt', sep = '\t', quoting=csv.QUOTE_NONE)

# %%
# #training and testing
# from sklearn.model_selection import train_test_split
# seed = 123
# train, test = train_test_split(df)
sent = list(train['#1 String']) + list(train['#2 String']) + list(test['#1 String']) + list(test['#2 String'])

# %%
def write_csv(result, id_col, path):
    result_final = pd.DataFrame(data = list(zip(id_col, result)), columns = ['id', 'prediction'])
    result_final.to_csv(path, index = False)

# %%
#loading the word vector
file_name = 'word_embedding/glove.6B.300d.txt'
embeddings = load_embedding(file_name)

# %%
#Creating the embedding matrix
NUM_WORDS = len(embeddings) #200000
tokenize = Tokenizer(num_words = NUM_WORDS)
tokenize.fit_on_texts(sent)
word_index = tokenize.word_index

sent1_train = tokenize.texts_to_sequences(train['#1 String'])
sent2_train = tokenize.texts_to_sequences(train['#2 String'])
sent1_test = tokenize.texts_to_sequences(test['#1 String'])
sent2_test = tokenize.texts_to_sequences(test['#2 String'])

max_seq_length = max_seq_len(sent1_train)
max_seq_length = max_seq_len(sent2_train, max_seq_length)
max_seq_length = max_seq_len(sent1_test, max_seq_length)
max_seq_length = max_seq_len(sent2_test, max_seq_length)

sent1_train_padded = pad_sequences(sent1_train, max_seq_length)
sent2_train_padded = pad_sequences(sent2_train, max_seq_length)
sent1_test_padded = pad_sequences(sent1_test, max_seq_length)
sent2_test_padded = pad_sequences(sent2_test, max_seq_length)
#Matrix with the embedding weights
embedding_dim = 300
embedding_weights = create_embedding_weights(embeddings, embedding_dim, word_index, NUM_WORDS)
NUM_WORDS = len(embedding_weights)
NUM_WORDS
# Out:
# 16539

# %% [markdown]
# ## Deep learning models

# %%
dl = deep_learning.deepModels(embedding_dim = embedding_dim,
                embedding_weights = embedding_weights,
                max_seq_length = max_seq_length,
                NUM_WORDS = NUM_WORDS)

# %% [markdown]
# ### Siamese LSTM

# %%
lstm = dl.siamese_lstm(dropout_lstm=None)

# %%
batch_size=32
epochs=15
validation_split=.1

# %%
hist_lstm = lstm.fit([sent1_train_padded, sent2_train_padded],
                     train['Quality'],
                     batch_size=batch_size, epochs=epochs, 
                     validation_split= validation_split)
# Out:
# Train on 3668 samples, validate on 408 samples
# Epoch 1/15
# 3668/3668 [==============================] - 19s 5ms/step - loss: 0.6219 - accuracy: 0.6775 - val_loss: 0.7663 - val_accuracy: 0.6961
# Epoch 2/15
# 3668/3668 [==============================] - 12s 3ms/step - loss: 0.3874 - accuracy: 0.8362 - val_loss: 0.6455 - val_accuracy: 0.6985
# Epoch 3/15
# 3668/3668 [==============================] - 11s 3ms/step - loss: 0.2706 - accuracy: 0.9024 - val_loss: 0.7166 - val_accuracy: 0.6961
# Epoch 4/15
# 3668/3668 [==============================] - 13s 3ms/step - loss: 0.1951 - accuracy: 0.9370 - val_loss: 0.6199 - val_accuracy: 0.7377
# Epoch 5/15
# 3668/3668 [==============================] - 16s 4ms/step - loss: 0.1505 - accuracy: 0.9545 - val_loss: 0.6746 - val_accuracy: 0.7328
# Epoch 6/15
# 3668/3668 [==============================] - 15s 4ms/step - loss: 0.1133 - accuracy: 0.9689 - val_loss: 0.8135 - val_accuracy: 0.7132
# Epoch 7/15
# 3668/3668 [==============================] - 16s 4ms/step - loss: 0.0808 - accuracy: 0.9793 - val_loss: 0.7076 - val_accuracy: 0.7206
# Epoch 8/15
# 3668/3668 [==============================] - 12s 3ms/step - loss: 0.0566 - accuracy: 0.9861 - val_loss: 0.7841 - val_accuracy: 0.7010
# Epoch 9/15
# 3668/3668 [==============================] - 11s 3ms/step - loss: 0.0466 - accuracy: 0.9891 - val_loss: 0.7369 - val_accuracy: 0.7647
# Epoch 10/15
# 3668/3668 [==============================] - 17s 5ms/step - loss: 0.0241 - accuracy: 0.9951 - val_loss: 0.8072 - val_accuracy: 0.7181
# Epoch 11/15
# 3668/3668 [==============================] - 15s 4ms/step - loss: 0.0201 - accuracy: 0.9970 - val_loss: 0.8337 - val_accuracy: 0.7598
# Epoch 12/15
# 3668/3668 [==============================] - 14s 4ms/step - loss: 0.0140 - accuracy: 0.9981 - val_loss: 0.8215 - val_accuracy: 0.7304
# Epoch 13/15
# 3668/3668 [==============================] - 16s 4ms/step - loss: 0.0119 - accuracy: 0.9989 - val_loss: 0.8503 - val_accuracy: 0.7574
# Epoch 14/15
# 3668/3668 [==============================] - 18s 5ms/step - loss: 0.0084 - accuracy: 0.9995 - val_loss: 0.9188 - val_accuracy: 0.7598
# Epoch 15/15
# 3668/3668 [==============================] - 18s 5ms/step - loss: 0.0072 - accuracy: 0.9995 - val_loss: 0.9113 - val_accuracy: 0.7574

# %%
pred_lstm = lstm.predict([sent1_test_padded, sent2_test_padded])

# %%
result_lstm = []
for i in pred_lstm:
    if i > .5:
        result_lstm.append(1)
    else:
        result_lstm.append(0)
        
count = 0
for i in range(len(result_lstm)):
    if result_lstm[i] == test['Quality'].to_numpy()[i]:
        count = count +1

accuracy = (count/len(result_lstm))*100

# %%
print('accuracy:'+ str(accuracy))
# Out:
# accuracy:71.65217391304348

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

# %%
print('f1_socre:' + str(f1_score(test['Quality'], result_lstm, average = 'weighted')))
print('recall_socre:' + str(recall_score(test['Quality'], result_lstm, average = 'weighted')))
print('precision_socre:' + str(precision_score(test['Quality'], result_lstm, average = 'weighted')))
# Out:
# f1_socre:0.6968130708906548
# recall_socre:0.7165217391304348
# precision_socre:0.7017193692543879

# %%
plot_model_training(hist_lstm)

# %%
write_csv(result_lstm, test['#1 ID'], 'results/deep_learning/MSR/lstm.csv')

# %% [markdown]
# ### Siamese GRU

# %%
gru = dl.Siamese_GRU()

# %%
batch_size=100
epochs=15
validation_split=.1

# %%
hist_gru = gru.fit([sent1_train_padded, 
                    sent2_train_padded],
                   train['Quality'],
                   batch_size=batch_size,
                   epochs=epochs, 
                   validation_split=validation_split)
# Out:
# Train on 3668 samples, validate on 408 samples
# Epoch 1/15
# 3668/3668 [==============================] - 10s 3ms/step - loss: 0.7241 - accuracy: 0.6388 - val_loss: 0.6242 - val_accuracy: 0.6961
# Epoch 2/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.3315 - accuracy: 0.8770 - val_loss: 0.6397 - val_accuracy: 0.6961
# Epoch 3/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.2608 - accuracy: 0.9117 - val_loss: 0.6676 - val_accuracy: 0.6961
# Epoch 4/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.2205 - accuracy: 0.9297 - val_loss: 0.6823 - val_accuracy: 0.6936
# Epoch 5/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.1930 - accuracy: 0.9387 - val_loss: 0.6677 - val_accuracy: 0.6961
# Epoch 6/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.1653 - accuracy: 0.9487 - val_loss: 0.7035 - val_accuracy: 0.7010
# Epoch 7/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.1480 - accuracy: 0.9539 - val_loss: 0.7096 - val_accuracy: 0.7132
# Epoch 8/15
# 3668/3668 [==============================] - 8s 2ms/step - loss: 0.1295 - accuracy: 0.9599 - val_loss: 0.7296 - val_accuracy: 0.7206
# Epoch 9/15
# 3668/3668 [==============================] - 8s 2ms/step - loss: 0.1155 - accuracy: 0.9637 - val_loss: 0.7137 - val_accuracy: 0.7059
# Epoch 10/15
# 3668/3668 [==============================] - 8s 2ms/step - loss: 0.0937 - accuracy: 0.9730 - val_loss: 0.7969 - val_accuracy: 0.7083
# Epoch 11/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.0789 - accuracy: 0.9746 - val_loss: 0.8583 - val_accuracy: 0.7010
# Epoch 12/15
# 3668/3668 [==============================] - 8s 2ms/step - loss: 0.0653 - accuracy: 0.9836 - val_loss: 0.8452 - val_accuracy: 0.6936
# Epoch 13/15
# 3668/3668 [==============================] - 8s 2ms/step - loss: 0.0459 - accuracy: 0.9877 - val_loss: 0.9363 - val_accuracy: 0.7083
# Epoch 14/15
# 3668/3668 [==============================] - 6s 2ms/step - loss: 0.0431 - accuracy: 0.9907 - val_loss: 0.9678 - val_accuracy: 0.7034
# Epoch 15/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.0338 - accuracy: 0.9959 - val_loss: 1.0267 - val_accuracy: 0.6936

# %%
pred_gru = gru.predict([sent1_test_padded, sent2_test_padded])

# %%
result_gru = []
for i in pred_gru:
    if i > .5:
        result_gru.append(1)
    else:
        result_gru.append(0)
        
count = 0
for i in range(len(result_gru)):
    if result_gru[i] == test['Quality'].to_numpy()[i]:
        count = count +1

accuracy = (count/len(result_gru))*100
accuracy
# Out:
# 69.73913043478261

# %%
print('f1_socre:' + str(f1_score(test['Quality'], result_gru, average = 'weighted')))
print('recall_socre:' + str(recall_score(test['Quality'], result_gru, average = 'weighted')))
print('precision_socre:' + str(precision_score(test['Quality'], result_gru, average = 'weighted')))
# Out:
# f1_socre:0.6817433653303219
# recall_socre:0.697391304347826
# precision_socre:0.6807703058114071

# %%
plot_model_training(hist_gru)

# %%
write_csv(result_gru, test['#1 ID'], 'results/deep_learning/MSR/gru.csv')

# %% [markdown]
# ### Siamese CNN

# %%
cnn = dl.siamese_cnn(filters= 16, kernel_size= 3)

# %%
hist_cnn = cnn.fit([sent1_train_padded, sent2_train_padded], 
                   train['Quality'], 
                   batch_size=batch_size, 
                   epochs=epochs, 
                   validation_split=validation_split)
# Out:
# Train on 3668 samples, validate on 408 samples
# Epoch 1/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.6377 - accuracy: 0.6557 - val_loss: 0.5932 - val_accuracy: 0.7108
# Epoch 2/15
# 3668/3668 [==============================] - 1s 145us/step - loss: 0.5772 - accuracy: 0.6933 - val_loss: 0.5929 - val_accuracy: 0.7132
# Epoch 3/15
# 3668/3668 [==============================] - 1s 183us/step - loss: 0.5395 - accuracy: 0.7146 - val_loss: 0.5938 - val_accuracy: 0.6863
# Epoch 4/15
# 3668/3668 [==============================] - 1s 248us/step - loss: 0.5019 - accuracy: 0.7527 - val_loss: 0.5840 - val_accuracy: 0.7059
# Epoch 5/15
# 3668/3668 [==============================] - 1s 253us/step - loss: 0.4612 - accuracy: 0.7876 - val_loss: 0.5956 - val_accuracy: 0.6887
# Epoch 6/15
# 3668/3668 [==============================] - 1s 194us/step - loss: 0.4126 - accuracy: 0.8299 - val_loss: 0.5861 - val_accuracy: 0.7157
# Epoch 7/15
# 3668/3668 [==============================] - 1s 246us/step - loss: 0.3621 - accuracy: 0.8640 - val_loss: 0.5981 - val_accuracy: 0.6985
# Epoch 8/15
# 3668/3668 [==============================] - 1s 256us/step - loss: 0.3111 - accuracy: 0.9010 - val_loss: 0.6137 - val_accuracy: 0.7059
# Epoch 9/15
# 3668/3668 [==============================] - 1s 246us/step - loss: 0.2675 - accuracy: 0.9269 - val_loss: 0.6358 - val_accuracy: 0.6789
# Epoch 10/15
# 3668/3668 [==============================] - 1s 246us/step - loss: 0.2197 - accuracy: 0.9534 - val_loss: 0.6543 - val_accuracy: 0.7010
# Epoch 11/15
# 3668/3668 [==============================] - 1s 240us/step - loss: 0.1765 - accuracy: 0.9738 - val_loss: 0.6782 - val_accuracy: 0.6667
# Epoch 12/15
# 3668/3668 [==============================] - 1s 241us/step - loss: 0.1458 - accuracy: 0.9801 - val_loss: 0.6962 - val_accuracy: 0.6691
# Epoch 13/15
# 3668/3668 [==============================] - 1s 248us/step - loss: 0.1147 - accuracy: 0.9883 - val_loss: 0.7178 - val_accuracy: 0.6765
# Epoch 14/15
# 3668/3668 [==============================] - 1s 248us/step - loss: 0.0885 - accuracy: 0.9954 - val_loss: 0.7570 - val_accuracy: 0.6887
# Epoch 15/15
# 3668/3668 [==============================] - 1s 255us/step - loss: 0.0672 - accuracy: 0.9978 - val_loss: 0.7937 - val_accuracy: 0.6912

# %%
pred_cnn = cnn.predict([sent1_test_padded, sent2_test_padded])

# %%
result_cnn = []
for i in pred_cnn:
    if i > .5:
        result_cnn.append(1)
    else:
        result_cnn.append(0)
        
count = 0
for i in range(len(result_cnn)):
    if result_cnn[i] == test['Quality'].to_numpy()[i]:
        count = count +1

accuracy = (count/len(result_cnn))*100
accuracy
# Out:
# 66.95652173913044

# %%
print('f1_socre:' + str(f1_score(test['Quality'], result_cnn, average = 'weighted')))
print('recall_socre:' + str(recall_score(test['Quality'], result_cnn, average = 'weighted')))
print('precision_socre:' + str(precision_score(test['Quality'], result_cnn, average = 'weighted')))
# Out:
# f1_socre:0.6527455449929226
# recall_socre:0.6695652173913044
# precision_socre:0.6491485389643118

# %%
plot_model_training(hist_cnn)

# %%
write_csv(result_cnn, test['#1 ID'], 'results/deep_learning/MSR/cnn.csv')

# %% [markdown]
# #### SNLI Benchmark

# %%
snli = dl.deep_nn()

# %%
hist_snli = snli.fit([sent1_train_padded, sent2_train_padded], 
                   train['Quality'], 
                   batch_size=batch_size, 
                   epochs=epochs, 
                   validation_split=validation_split)
# Out:
# Train on 3668 samples, validate on 408 samples
# Epoch 1/15
# 3668/3668 [==============================] - 3s 829us/step - loss: 0.7495 - accuracy: 0.5728 - val_loss: 0.6104 - val_accuracy: 0.6961
# Epoch 2/15
# 3668/3668 [==============================] - 1s 257us/step - loss: 0.6696 - accuracy: 0.6352 - val_loss: 0.6048 - val_accuracy: 0.6961
# Epoch 3/15
# 3668/3668 [==============================] - 1s 405us/step - loss: 0.6597 - accuracy: 0.6549 - val_loss: 0.6048 - val_accuracy: 0.6912
# Epoch 4/15
# 3668/3668 [==============================] - 2s 412us/step - loss: 0.6163 - accuracy: 0.6737 - val_loss: 0.5982 - val_accuracy: 0.7132
# Epoch 5/15
# 3668/3668 [==============================] - 1s 406us/step - loss: 0.5899 - accuracy: 0.6930 - val_loss: 0.5839 - val_accuracy: 0.7132
# Epoch 6/15
# 3668/3668 [==============================] - 1s 405us/step - loss: 0.5647 - accuracy: 0.7124 - val_loss: 0.6375 - val_accuracy: 0.7083
# Epoch 7/15
# 3668/3668 [==============================] - 1s 378us/step - loss: 0.5320 - accuracy: 0.7399 - val_loss: 1.2282 - val_accuracy: 0.3064
# Epoch 8/15
# 3668/3668 [==============================] - 1s 389us/step - loss: 0.4572 - accuracy: 0.7936 - val_loss: 1.0332 - val_accuracy: 0.3039
# Epoch 9/15
# 3668/3668 [==============================] - 1s 337us/step - loss: 0.3986 - accuracy: 0.8222 - val_loss: 2.0202 - val_accuracy: 0.3039
# Epoch 10/15
# 3668/3668 [==============================] - 1s 401us/step - loss: 0.3540 - accuracy: 0.8451 - val_loss: 0.6840 - val_accuracy: 0.5735
# Epoch 11/15
# 3668/3668 [==============================] - 1s 315us/step - loss: 0.2900 - accuracy: 0.8779 - val_loss: 1.0642 - val_accuracy: 0.4510
# Epoch 12/15
# 3668/3668 [==============================] - 1s 281us/step - loss: 0.2624 - accuracy: 0.8923 - val_loss: 0.6413 - val_accuracy: 0.6618
# Epoch 13/15
# 3668/3668 [==============================] - 1s 399us/step - loss: 0.1940 - accuracy: 0.9220 - val_loss: 0.7510 - val_accuracy: 0.5760
# Epoch 14/15
# 3668/3668 [==============================] - 1s 399us/step - loss: 0.1452 - accuracy: 0.9479 - val_loss: 0.6972 - val_accuracy: 0.7181
# Epoch 15/15
# 3668/3668 [==============================] - 1s 388us/step - loss: 0.1184 - accuracy: 0.9526 - val_loss: 0.8673 - val_accuracy: 0.7132

# %%
pred_snli = snli.predict([sent1_test_padded, sent2_test_padded])

# %%
result_snli = []
for i in pred_snli:
    if i > .5:
        result_snli.append(1)
    else:
        result_snli.append(0)
        
count = 0
for i in range(len(result_snli)):
    if result_snli[i] == test['Quality'].to_numpy()[i]:
        count = count +1

accuracy = (count/len(result_snli))*100
accuracy
# Out:
# 69.27536231884058

# %%
print('f1_socre:' + str(f1_score(test['Quality'], result_snli, average = 'weighted')))
print('recall_socre:' + str(recall_score(test['Quality'], result_snli, average = 'weighted')))
print('precision_socre:' + str(precision_score(test['Quality'], result_snli, average = 'weighted')))
# Out:
# f1_socre:0.6310725010858421
# recall_socre:0.6927536231884058
# precision_socre:0.6800222391644275

# %%
plot_model_training(hist_snli)

# %%
write_csv(result_snli, test['#1 ID'], 'results/deep_learning/MSR/deep_nn.csv')

# %% [markdown]
# ### Hybrid CNN-LSTM

# %%
hybrid = dl.hybrid_model()

# %%
hist_hybrid = hybrid.fit([sent1_train_padded, sent2_train_padded], 
                   train['Quality'], 
                   batch_size=batch_size, 
                   epochs=epochs, 
                   validation_split=validation_split)
# Out:
# Train on 3668 samples, validate on 408 samples
# Epoch 1/15
# 3668/3668 [==============================] - 5s 1ms/step - loss: 0.6501 - accuracy: 0.6529 - val_loss: 0.6058 - val_accuracy: 0.6961
# Epoch 2/15
# 3668/3668 [==============================] - 1s 306us/step - loss: 0.6149 - accuracy: 0.6709 - val_loss: 0.5855 - val_accuracy: 0.6961
# Epoch 3/15
# 3668/3668 [==============================] - 1s 290us/step - loss: 0.5951 - accuracy: 0.6712 - val_loss: 0.5825 - val_accuracy: 0.7132
# Epoch 4/15
# 3668/3668 [==============================] - 1s 280us/step - loss: 0.5682 - accuracy: 0.6944 - val_loss: 0.5957 - val_accuracy: 0.6691
# Epoch 5/15
# 3668/3668 [==============================] - 1s 283us/step - loss: 0.5393 - accuracy: 0.7110 - val_loss: 0.5971 - val_accuracy: 0.6912
# Epoch 6/15
# 3668/3668 [==============================] - 1s 257us/step - loss: 0.4920 - accuracy: 0.7429 - val_loss: 0.6078 - val_accuracy: 0.6936
# Epoch 7/15
# 3668/3668 [==============================] - 1s 242us/step - loss: 0.4440 - accuracy: 0.7707 - val_loss: 0.6637 - val_accuracy: 0.6985
# Epoch 8/15
# 3668/3668 [==============================] - 1s 386us/step - loss: 0.3925 - accuracy: 0.8013 - val_loss: 0.7172 - val_accuracy: 0.6789
# Epoch 9/15
# 3668/3668 [==============================] - 1s 287us/step - loss: 0.3549 - accuracy: 0.8252 - val_loss: 0.7822 - val_accuracy: 0.6324
# Epoch 10/15
# 3668/3668 [==============================] - 1s 230us/step - loss: 0.3348 - accuracy: 0.8342 - val_loss: 0.8390 - val_accuracy: 0.6324
# Epoch 11/15
# 3668/3668 [==============================] - 1s 284us/step - loss: 0.2946 - accuracy: 0.8484 - val_loss: 0.9180 - val_accuracy: 0.6863 loss:
# Epoch 12/15
# 3668/3668 [==============================] - 2s 441us/step - loss: 0.2785 - accuracy: 0.8659 - val_loss: 0.9843 - val_accuracy: 0.6912
# Epoch 13/15
# 3668/3668 [==============================] - 2s 491us/step - loss: 0.2573 - accuracy: 0.8659 - val_loss: 1.0666 - val_accuracy: 0.6127
# Epoch 14/15
# 3668/3668 [==============================] - 1s 316us/step - loss: 0.2506 - accuracy: 0.8757 - val_loss: 1.0745 - val_accuracy: 0.6838
# Epoch 15/15
# 3668/3668 [==============================] - 1s 372us/step - loss: 0.2384 - accuracy: 0.8798 - val_loss: 1.1392 - val_accuracy: 0.6593

# %%
pred_hybrid = hybrid.predict([sent1_test_padded, sent2_test_padded])

# %%
result_hybrid = []
for i in pred_hybrid:
    if i > .5:
        result_hybrid.append(1)
    else:
        result_hybrid.append(0)
        
count = 0
for i in range(len(result_hybrid)):
    if result_hybrid[i] == test['Quality'].to_numpy()[i]:
        count = count +1

accuracy = (count/len(result_hybrid))*100
accuracy
# Out:
# 60.98550724637681

# %%
print('f1_socre:' + str(f1_score(test['Quality'], result_hybrid, average = 'weighted')))
print('recall_socre:' + str(recall_score(test['Quality'], result_hybrid, average = 'weighted')))
print('precision_socre:' + str(precision_score(test['Quality'], result_hybrid, average = 'weighted')))
# Out:
# f1_socre:0.5957379156140158
# recall_socre:0.6098550724637681
# precision_socre:0.5880538987440882

# %%
plot_model_training(hist_hybrid)

# %%
write_csv(result_hybrid, test['#1 ID'], 'results/deep_learning/MSR/hybrid.csv')

# %% [markdown]
# ### Enhanced LSTM

# %%
e_lstm = dl.enhanced_lstm()

# %%
hist_e_lstm = e_lstm.fit([sent1_train_padded, sent2_train_padded], 
                   train['Quality'], 
                   batch_size=batch_size, 
                   epochs=epochs, 
                   validation_split=validation_split)
# Out:
# Train on 3668 samples, validate on 408 samples
# Epoch 1/15
# 3668/3668 [==============================] - 42s 11ms/step - loss: 0.7738 - accuracy: 0.6254 - val_loss: 0.6039 - val_accuracy: 0.6961
# Epoch 2/15
# 3668/3668 [==============================] - 31s 8ms/step - loss: 0.5474 - accuracy: 0.7257 - val_loss: 0.6703 - val_accuracy: 0.6961
# Epoch 3/15
# 3668/3668 [==============================] - 31s 8ms/step - loss: 0.4845 - accuracy: 0.7748 - val_loss: 0.7229 - val_accuracy: 0.6961
# Epoch 4/15
# 3668/3668 [==============================] - 33s 9ms/step - loss: 0.3765 - accuracy: 0.8400 - val_loss: 0.7581 - val_accuracy: 0.6961
# Epoch 5/15
# 3668/3668 [==============================] - 32s 9ms/step - loss: 0.3035 - accuracy: 0.8705 - val_loss: 0.9313 - val_accuracy: 0.7010
# Epoch 6/15
# 3668/3668 [==============================] - 35s 10ms/step - loss: 0.2138 - accuracy: 0.9117 - val_loss: 0.7605 - val_accuracy: 0.7010
# Epoch 7/15
# 3668/3668 [==============================] - 34s 9ms/step - loss: 0.1501 - accuracy: 0.9463 - val_loss: 1.2280 - val_accuracy: 0.6961
# Epoch 8/15
# 3668/3668 [==============================] - 35s 9ms/step - loss: 0.0760 - accuracy: 0.9733 - val_loss: 0.9741 - val_accuracy: 0.7206
# Epoch 9/15
# 3668/3668 [==============================] - 34s 9ms/step - loss: 0.0888 - accuracy: 0.9689 - val_loss: 0.8913 - val_accuracy: 0.7206
# Epoch 10/15
# 3668/3668 [==============================] - 34s 9ms/step - loss: 0.0750 - accuracy: 0.9752 - val_loss: 1.2305 - val_accuracy: 0.6985
# Epoch 11/15
# 3668/3668 [==============================] - 33s 9ms/step - loss: 0.0622 - accuracy: 0.9782 - val_loss: 0.9582 - val_accuracy: 0.7328
# Epoch 12/15
# 3668/3668 [==============================] - 34s 9ms/step - loss: 0.0460 - accuracy: 0.9850 - val_loss: 1.0332 - val_accuracy: 0.7255
# Epoch 13/15
# 3668/3668 [==============================] - 35s 9ms/step - loss: 0.0318 - accuracy: 0.9902 - val_loss: 1.1134 - val_accuracy: 0.7353
# Epoch 14/15
# 3668/3668 [==============================] - 29s 8ms/step - loss: 0.0358 - accuracy: 0.9883 - val_loss: 1.3668 - val_accuracy: 0.7279
# Epoch 15/15
# 3668/3668 [==============================] - 31s 8ms/step - loss: 0.0240 - accuracy: 0.9915 - val_loss: 1.1539 - val_accuracy: 0.7426

# %%
pred_e_lstm = e_lstm.predict([sent1_test_padded, sent2_test_padded])

# %%
result_e_lstm = []
for i in pred_e_lstm:
    if i > .5:
        result_e_lstm.append(1)
    else:
        result_e_lstm.append(0)
        
count = 0
for i in range(len(result_e_lstm)):
    if result_e_lstm[i] == test['Quality'].to_numpy()[i]:
        count = count +1

accuracy = (count/len(result_e_lstm))*100
accuracy
# Out:
# 73.56521739130434

# %%
print('f1_socre:' + str(f1_score(test['Quality'], result_e_lstm, average = 'weighted')))
print('recall_socre:' + str(recall_score(test['Quality'], result_e_lstm, average = 'weighted')))
print('precision_socre:' + str(precision_score(test['Quality'], result_e_lstm, average = 'weighted')))
# Out:
# f1_socre:0.7086940120759124
# recall_socre:0.7356521739130435
# precision_socre:0.728904508540574

# %%
plot_model_training(hist_e_lstm)

# %%
write_csv(result_e_lstm, test['#1 ID'], 'results/deep_learning/MSR/elstm.csv')
