# %% [markdown]
# # Executing all the modules

# %%
# import statements
import pandas as pd
import numpy as np
from tqdm import tqdm
from keras.models import Sequential, Model
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import LSTM, GRU
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
from keras.layers import Input, concatenate, dot, Flatten, Reshape, Bidirectional, add
from keras.layers import TimeDistributed, Lambda
from keras.layers import Convolution1D, GlobalMaxPooling1D
from keras.regularizers import l2
from keras.layers import dot, Dot
from keras.activations import softmax
from keras.layers import Permute, subtract, multiply, GlobalAvgPool1D, GlobalMaxPool1D
from keras.callbacks import ModelCheckpoint
from keras import backend as K
from keras.layers.advanced_activations import PReLU
from keras.optimizers import Adadelta
import keras.backend as K
import tensorflow as tf
from keras.layers import Conv1D, MaxPooling1D, Embedding
from keras.preprocessing import sequence, text
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, recall_score, precision_score
import functions.utils as utils
from functions.utils import *
import models.deep_learning as deep_learning
from models.deep_learning import *
from functions.model_evaluation import *
import functions.model_evaluation
from sklearn.model_selection import train_test_split
import csv
# Out:
# Using TensorFlow backend.

# %%
def write_csv(result, id_col, path):
    result_final = pd.DataFrame(data = list(zip(id_col, result)), columns = ['id', 'prediction'])
    result_final.to_csv(path, index = False)

# %%
#loading the word vector
file_name = 'word_embedding/glove.6B.300d.txt'
embeddings = load_embedding(file_name)

# %% [markdown]
# ## Quora Dataset: Preprocessing

# %%
#Loading the data
df = pd.read_csv('Data/train.csv')
df['question1'] = df['question1'].apply(str)
df['question2'] = df['question2'].apply(str)
df.dropna(inplace = True)
df = df[:1000]

#training and testing
seed = 123
train, test = train_test_split(df)
q = list(train['question1']) + list(train['question2']) + list(test['question1']) + list(test['question2'])
#Creating the embedding matrix
NUM_WORDS = len(embeddings) #200000
tokenize = Tokenizer(num_words = NUM_WORDS)
tokenize.fit_on_texts(q)
word_index = tokenize.word_index

q1_train = tokenize.texts_to_sequences(train['question1'])
q2_train = tokenize.texts_to_sequences(train['question2'])
q1_test = tokenize.texts_to_sequences(test['question1'])
q2_test = tokenize.texts_to_sequences(test['question2'])

max_seq_length = max_seq_len(q1_train)
max_seq_length = max_seq_len(q2_train, max_seq_length)
max_seq_length = max_seq_len(q1_test, max_seq_length)
max_seq_length = max_seq_len(q2_test, max_seq_length)

q1_train_padded = pad_sequences(q1_train, max_seq_length)
q2_train_padded = pad_sequences(q2_train, max_seq_length)
q1_test_padded = pad_sequences(q1_test, max_seq_length)
q2_test_padded = pad_sequences(q2_test, max_seq_length)

#Matrix with the embedding weights
embedding_dim = 300
embedding_weights = create_embedding_weights(embeddings, embedding_dim, word_index, NUM_WORDS)

NUM_WORDS = len(embedding_weights)
print("NUM of Words:"+ str(NUM_WORDS))
# Out:
# NUM of Words:4004

# %% [markdown]
# ## Deep Learning models

# %%
dl = deep_learning.deepModels(embedding_dim = embedding_dim,
                embedding_weights = embedding_weights,
                max_seq_length = max_seq_length,
                NUM_WORDS = NUM_WORDS)

# %% [markdown]
# ### Siamese LSTM

# %%
# variables
batch_size=32
epochs=15
validation_split=.1

# %%
lstm = dl.siamese_lstm()

hist_lstm = lstm.fit([q1_train_padded, q2_train_padded],
                     train['is_duplicate'],
                     batch_size=batch_size, epochs=epochs, 
                     validation_split= validation_split)

pred_lstm = lstm.predict([q1_test_padded, q2_test_padded])

result_lstm = []
for i in pred_lstm:
    if i > .5:
        result_lstm.append(1)
    else:
        result_lstm.append(0)
        
count = 0
for i in range(len(result_lstm)):
    if result_lstm[i] == test['is_duplicate'].to_numpy()[i]:
        count = count +1

print("SIAMESE LSTM:")
accuracy = (count/len(result_lstm))*100
print('accuracy: ' + str(accuracy))
print('f1_socre:' + str(f1_score(test['is_duplicate'], result_lstm, average = 'weighted')))
print('recall_socre:' + str(recall_score(test['is_duplicate'], result_lstm, average = 'weighted')))
print('precision_socre:' + str(precision_score(test['is_duplicate'], result_lstm, average = 'weighted')))
plot_model_training(hist_lstm)

#write_csv(result_lstm, test['id'], 'results/deep_learning/quora/lstm.csv')
# Out:
# Train on 675 samples, validate on 75 samples
# Epoch 1/15
# 675/675 [==============================] - 6s 9ms/step - loss: 0.7539 - accuracy: 0.5437 - val_loss: 1.1095 - val_accuracy: 0.3467
# Epoch 2/15
# 675/675 [==============================] - 3s 5ms/step - loss: 0.3960 - accuracy: 0.8281 - val_loss: 0.6772 - val_accuracy: 0.6133
# Epoch 3/15
# 675/675 [==============================] - 3s 4ms/step - loss: 0.2464 - accuracy: 0.9259 - val_loss: 0.9836 - val_accuracy: 0.3467
# Epoch 4/15
# 675/675 [==============================] - 3s 4ms/step - loss: 0.2093 - accuracy: 0.9481 - val_loss: 0.9375 - val_accuracy: 0.3467
# Epoch 5/15
# 675/675 [==============================] - 4s 5ms/step - loss: 0.1664 - accuracy: 0.9556 - val_loss: 0.9648 - val_accuracy: 0.3467
# Epoch 6/15
# 675/675 [==============================] - 4s 6ms/step - loss: 0.1382 - accuracy: 0.9615 - val_loss: 0.8302 - val_accuracy: 0.3467
# Epoch 7/15
# 675/675 [==============================] - 4s 6ms/step - loss: 0.1213 - accuracy: 0.9778 - val_loss: 0.8903 - val_accuracy: 0.3467
# Epoch 8/15
# 675/675 [==============================] - 3s 4ms/step - loss: 0.0965 - accuracy: 0.9793 - val_loss: 0.8326 - val_accuracy: 0.3467
# Epoch 9/15
# 675/675 [==============================] - 3s 4ms/step - loss: 0.0837 - accuracy: 0.9867 - val_loss: 0.9745 - val_accuracy: 0.3600
# Epoch 10/15
# 675/675 [==============================] - 4s 5ms/step - loss: 0.0797 - accuracy: 0.9807 - val_loss: 1.0040 - val_accuracy: 0.3600
# Epoch 11/15
# 675/675 [==============================] - 4s 6ms/step - loss: 0.0813 - accuracy: 0.9822 - val_loss: 0.9861 - val_accuracy: 0.3600
# Epoch 12/15
# 675/675 [==============================] - 3s 4ms/step - loss: 0.0680 - accuracy: 0.9807 - val_loss: 0.7565 - val_accuracy: 0.5333
# Epoch 13/15
# 675/675 [==============================] - 3s 4ms/step - loss: 0.0584 - accuracy: 0.9941 - val_loss: 0.8322 - val_accuracy: 0.4800
# Epoch 14/15
# 675/675 [==============================] - 3s 5ms/step - loss: 0.0550 - accuracy: 0.9926 - val_loss: 0.9411 - val_accuracy: 0.4400
# Epoch 15/15
# 675/675 [==============================] - 4s 6ms/step - loss: 0.0496 - accuracy: 0.9911 - val_loss: 0.8668 - val_accuracy: 0.4800
# SIAMESE LSTM:
# accuracy: 54.800000000000004
# f1_socre:0.5182244379212516
# recall_socre:0.548
# precision_socre:0.7368722600151172

# %% [markdown]
# ### Siamese GRU

# %%
batch_size=100
epochs=15
validation_split=.1

gru = dl.Siamese_GRU()

hist_gru = gru.fit([q1_train_padded, 
                    q2_train_padded],
                   train['is_duplicate'],
                   batch_size=batch_size,
                   epochs=epochs, 
                   validation_split=validation_split)

pred_gru = gru.predict([q1_test_padded, q2_test_padded])

result_gru = []
for i in pred_gru:
    if i > .5:
        result_gru.append(1)
    else:
        result_gru.append(0)
        
count = 0
for i in range(len(result_gru)):
    if result_gru[i] == test['is_duplicate'].to_numpy()[i]:
        count = count +1
print("SIAMESE GRU:")
accuracy = (count/len(result_gru))*100
print("accuracy: " + str(accuracy))
print('f1_socre:' + str(f1_score(test['is_duplicate'], result_gru, average = 'weighted')))
print('recall_socre:' + str(recall_score(test['is_duplicate'], result_gru, average = 'weighted')))
print('precision_socre:' + str(precision_score(test['is_duplicate'], result_gru, average = 'weighted')))

#write_csv(result_gru, test['id'], 'results/deep_learning/quora/gru.csv')
# Out:
# Train on 675 samples, validate on 75 samples
# Epoch 1/15
# 675/675 [==============================] - 4s 6ms/step - loss: 0.7586 - accuracy: 0.5896 - val_loss: 1.1521 - val_accuracy: 0.3467
# Epoch 2/15
# 675/675 [==============================] - 2s 3ms/step - loss: 0.2992 - accuracy: 0.9037 - val_loss: 0.9669 - val_accuracy: 0.3467
# Epoch 3/15
# 675/675 [==============================] - 2s 3ms/step - loss: 0.2223 - accuracy: 0.9289 - val_loss: 1.0268 - val_accuracy: 0.3467
# Epoch 4/15
# 675/675 [==============================] - 2s 3ms/step - loss: 0.1820 - accuracy: 0.9378 - val_loss: 0.9153 - val_accuracy: 0.3467
# Epoch 5/15
# 675/675 [==============================] - 2s 2ms/step - loss: 0.1571 - accuracy: 0.9526 - val_loss: 0.9617 - val_accuracy: 0.3467
# Epoch 6/15
# 675/675 [==============================] - 2s 2ms/step - loss: 0.1325 - accuracy: 0.9600 - val_loss: 0.9557 - val_accuracy: 0.3467
# Epoch 7/15
# 675/675 [==============================] - 2s 2ms/step - loss: 0.1169 - accuracy: 0.9644 - val_loss: 0.9017 - val_accuracy: 0.3467
# Epoch 8/15
# 675/675 [==============================] - 1s 2ms/step - loss: 0.1070 - accuracy: 0.9659 - val_loss: 0.8375 - val_accuracy: 0.3600
# Epoch 9/15
# 675/675 [==============================] - 1s 2ms/step - loss: 0.0969 - accuracy: 0.9763 - val_loss: 0.8664 - val_accuracy: 0.3467
# Epoch 10/15
# 675/675 [==============================] - 1s 2ms/step - loss: 0.0956 - accuracy: 0.9659 - val_loss: 0.8490 - val_accuracy: 0.3600
# Epoch 11/15
# 675/675 [==============================] - 1s 2ms/step - loss: 0.0808 - accuracy: 0.9807 - val_loss: 0.8628 - val_accuracy: 0.3600
# Epoch 12/15
# 675/675 [==============================] - 2s 2ms/step - loss: 0.0741 - accuracy: 0.9807 - val_loss: 0.8555 - val_accuracy: 0.3867
# Epoch 13/15
# 675/675 [==============================] - 1s 2ms/step - loss: 0.0632 - accuracy: 0.9911 - val_loss: 0.9136 - val_accuracy: 0.3600
# Epoch 14/15
# 675/675 [==============================] - 1s 2ms/step - loss: 0.0629 - accuracy: 0.9807 - val_loss: 0.8046 - val_accuracy: 0.4400
# Epoch 15/15
# 675/675 [==============================] - 2s 2ms/step - loss: 0.0505 - accuracy: 0.9926 - val_loss: 0.9103 - val_accuracy: 0.3733
# SIAMESE GRU:
# accuracy: 39.6
# f1_socre:0.2691836464720499
# recall_socre:0.396
# precision_socre:0.611672268907563

# %% [markdown]
# ### Siamese CNN

# %%
batch_size = 100
epochs = 15
validation_split = 0.1

cnn = dl.siamese_cnn(filters= 16, kernel_size= 3)

hist_cnn = cnn.fit([q1_train_padded, q2_train_padded], 
                   train['is_duplicate'], 
                   batch_size=batch_size, 
                   epochs=epochs, 
                   validation_split=validation_split)

pred_cnn = cnn.predict([q1_test_padded, q2_test_padded])

result_cnn = []
for i in pred_cnn:
    if i > .5:
        result_cnn.append(1)
    else:
        result_cnn.append(0)
        
count = 0
for i in range(len(result_cnn)):
    if result_cnn[i] == test['is_duplicate'].to_numpy()[i]:
        count = count +1

accuracy = (count/len(result_cnn))*100
print("accuracy: " + str(accuracy))

print('f1_socre:' + str(f1_score(test['is_duplicate'], result_cnn, average = 'weighted')))
print('recall_socre:' + str(recall_score(test['is_duplicate'], result_cnn, average = 'weighted')))
print('precision_socre:' + str(precision_score(test['is_duplicate'], result_cnn, average = 'weighted')))

plot_model_training(hist_cnn)
#write_csv(result_cnn, test['id'], 'results/deep_learning/quora/cnn.csv')
# Out:
# Train on 675 samples, validate on 75 samples
# Epoch 1/15
# 675/675 [==============================] - 6s 9ms/step - loss: 0.6745 - accuracy: 0.6074 - val_loss: 0.6321 - val_accuracy: 0.6667
# Epoch 2/15
# 675/675 [==============================] - 0s 132us/step - loss: 0.6308 - accuracy: 0.6400 - val_loss: 0.6098 - val_accuracy: 0.6667
# Epoch 3/15
# 675/675 [==============================] - 0s 151us/step - loss: 0.6103 - accuracy: 0.6385 - val_loss: 0.6182 - val_accuracy: 0.6800
# Epoch 4/15
# 675/675 [==============================] - 0s 143us/step - loss: 0.5857 - accuracy: 0.6904 - val_loss: 0.5998 - val_accuracy: 0.7200
# Epoch 5/15
# 675/675 [==============================] - 0s 146us/step - loss: 0.5628 - accuracy: 0.6919 - val_loss: 0.5910 - val_accuracy: 0.7333
# Epoch 6/15
# 675/675 [==============================] - 0s 145us/step - loss: 0.5398 - accuracy: 0.7600 - val_loss: 0.5951 - val_accuracy: 0.6933
# Epoch 7/15
# 675/675 [==============================] - 0s 148us/step - loss: 0.5170 - accuracy: 0.7378 - val_loss: 0.5762 - val_accuracy: 0.7600
# Epoch 8/15
# 675/675 [==============================] - 0s 93us/step - loss: 0.4931 - accuracy: 0.7763 - val_loss: 0.5820 - val_accuracy: 0.6667
# Epoch 9/15
# 675/675 [==============================] - 0s 139us/step - loss: 0.4704 - accuracy: 0.7956 - val_loss: 0.5685 - val_accuracy: 0.7733
# Epoch 10/15
# 675/675 [==============================] - 0s 146us/step - loss: 0.4429 - accuracy: 0.8444 - val_loss: 0.5623 - val_accuracy: 0.7467
# Epoch 11/15
# 675/675 [==============================] - 0s 121us/step - loss: 0.4177 - accuracy: 0.8519 - val_loss: 0.5555 - val_accuracy: 0.7600
# Epoch 12/15
# 675/675 [==============================] - 0s 106us/step - loss: 0.3903 - accuracy: 0.8785 - val_loss: 0.5475 - val_accuracy: 0.7467
# Epoch 13/15
# 675/675 [==============================] - 0s 106us/step - loss: 0.3630 - accuracy: 0.8963 - val_loss: 0.5459 - val_accuracy: 0.7333
# Epoch 14/15
# 675/675 [==============================] - 0s 154us/step - loss: 0.3393 - accuracy: 0.8933 - val_loss: 0.5608 - val_accuracy: 0.7333
# Epoch 15/15
# 675/675 [==============================] - 0s 143us/step - loss: 0.3184 - accuracy: 0.9170 - val_loss: 0.5477 - val_accuracy: 0.7333
# accuracy: 66.4
# f1_socre:0.6140685483870968
# recall_socre:0.664
# precision_socre:0.6544425249169435

# %% [markdown]
# ## Deep NN

# %%
batch_size = 100
epochs = 15
validation_split = 0.1

snli = dl.deep_nn()

hist_snli = snli.fit([q1_train_padded, q2_train_padded], 
                   train['is_duplicate'], 
                   batch_size=batch_size, 
                   epochs=epochs, 
                   validation_split=validation_split)

pred_snli = snli.predict([q1_test_padded, q2_test_padded])

result_snli = []
for i in pred_snli:
    if i > .5:
        result_snli.append(1)
    else:
        result_snli.append(0)
        
count = 0
for i in range(len(result_snli)):
    if result_snli[i] == test['is_duplicate'].to_numpy()[i]:
        count = count +1

accuracy = (count/len(result_snli))*100
print("accuracy: " + str(accuracy))

print('f1_socre:' + str(f1_score(test['is_duplicate'], result_snli, average = 'weighted')))
print('recall_socre:' + str(recall_score(test['is_duplicate'], result_snli, average = 'weighted')))
print('precision_socre:' + str(precision_score(test['is_duplicate'], result_snli, average = 'weighted')))

#write_csv(result_snli, test['id'], 'results/deep_learning/quora/deep_nn.csv')
# Out:
# Train on 675 samples, validate on 75 samples
# Epoch 1/15
# 675/675 [==============================] - 3s 4ms/step - loss: 0.8646 - accuracy: 0.5170 - val_loss: 0.6531 - val_accuracy: 0.6533
# Epoch 2/15
# 675/675 [==============================] - 0s 331us/step - loss: 0.7298 - accuracy: 0.6015 - val_loss: 0.6409 - val_accuracy: 0.6533
# Epoch 3/15
# 675/675 [==============================] - 0s 293us/step - loss: 0.6072 - accuracy: 0.6963 - val_loss: 0.6518 - val_accuracy: 0.6533
# Epoch 4/15
# 675/675 [==============================] - 0s 281us/step - loss: 0.5891 - accuracy: 0.7215 - val_loss: 0.6546 - val_accuracy: 0.6533
# Epoch 5/15
# 675/675 [==============================] - 0s 253us/step - loss: 0.5079 - accuracy: 0.7452 - val_loss: 0.6465 - val_accuracy: 0.6533
# Epoch 6/15
# 675/675 [==============================] - 0s 195us/step - loss: 0.4524 - accuracy: 0.7733 - val_loss: 0.6776 - val_accuracy: 0.6533
# Epoch 7/15
# 675/675 [==============================] - 0s 254us/step - loss: 0.4316 - accuracy: 0.8059 - val_loss: 0.6610 - val_accuracy: 0.6533
# Epoch 8/15
# 675/675 [==============================] - 0s 266us/step - loss: 0.4048 - accuracy: 0.8119 - val_loss: 0.6467 - val_accuracy: 0.6533
# Epoch 9/15
# 675/675 [==============================] - 0s 232us/step - loss: 0.2717 - accuracy: 0.8800 - val_loss: 0.6875 - val_accuracy: 0.6533
# Epoch 10/15
# 675/675 [==============================] - 0s 201us/step - loss: 0.2452 - accuracy: 0.9081 - val_loss: 0.6287 - val_accuracy: 0.6400
# Epoch 11/15
# 675/675 [==============================] - 0s 223us/step - loss: 0.2341 - accuracy: 0.9007 - val_loss: 0.7925 - val_accuracy: 0.6533
# Epoch 12/15
# 675/675 [==============================] - 0s 186us/step - loss: 0.1895 - accuracy: 0.9230 - val_loss: 0.6202 - val_accuracy: 0.6533
# Epoch 13/15
# 675/675 [==============================] - 0s 186us/step - loss: 0.1444 - accuracy: 0.9526 - val_loss: 0.6658 - val_accuracy: 0.6533
# Epoch 14/15
# 675/675 [==============================] - 0s 230us/step - loss: 0.0903 - accuracy: 0.9644 - val_loss: 0.6387 - val_accuracy: 0.6400
# Epoch 15/15
# 675/675 [==============================] - 0s 169us/step - loss: 0.0628 - accuracy: 0.9733 - val_loss: 0.6802 - val_accuracy: 0.6400
# accuracy: 56.39999999999999
# f1_socre:0.5589895576428607
# recall_socre:0.564
# precision_socre:0.5553666092943201

# %% [markdown]
# ### Hybrid CNN-LSTM

# %%
batch_size = 100
epochs = 15
validation_split = 0.1

hybrid = dl.hybrid_model()

hist_hybrid = hybrid.fit([q1_train_padded, q2_train_padded], 
                   train['is_duplicate'], 
                   batch_size=batch_size, 
                   epochs=epochs, 
                   validation_split=validation_split)

pred_hybrid = hybrid.predict([q1_test_padded, q2_test_padded])

result_hybrid = []
for i in pred_hybrid:
    if i > .5:
        result_hybrid.append(1)
    else:
        result_hybrid.append(0)
        
count = 0
for i in range(len(result_hybrid)):
    if result_hybrid[i] == test['is_duplicate'].to_numpy()[i]:
        count = count +1

accuracy = (count/len(result_hybrid))*100
print("accuracy: " + str(accuracy))

print('f1_socre:' + str(f1_score(test['is_duplicate'], result_hybrid, average = 'weighted')))
print('recall_socre:' + str(recall_score(test['is_duplicate'], result_hybrid, average = 'weighted')))
print('precision_socre:' + str(precision_score(test['is_duplicate'], result_hybrid, average = 'weighted')))

plot_model_training(hist_hybrid)

#write_csv(result_hybrid, test['id'], 'results/deep_learning/quora/hybrid.csv')
# Out:
# Train on 675 samples, validate on 75 samples
# Epoch 1/15
# 675/675 [==============================] - 4s 6ms/step - loss: 0.6804 - accuracy: 0.5852 - val_loss: 0.6686 - val_accuracy: 0.6533
# Epoch 2/15
# 675/675 [==============================] - 1s 776us/step - loss: 0.6607 - accuracy: 0.6133 - val_loss: 0.6307 - val_accuracy: 0.6533
# Epoch 3/15
# 675/675 [==============================] - 0s 697us/step - loss: 0.6484 - accuracy: 0.6415 - val_loss: 0.6173 - val_accuracy: 0.6533
# Epoch 4/15
# 675/675 [==============================] - 1s 757us/step - loss: 0.6210 - accuracy: 0.6504 - val_loss: 0.6393 - val_accuracy: 0.6267
# Epoch 5/15
# 675/675 [==============================] - 0s 423us/step - loss: 0.5932 - accuracy: 0.6489 - val_loss: 0.5788 - val_accuracy: 0.7200
# Epoch 6/15
# 675/675 [==============================] - 0s 353us/step - loss: 0.5564 - accuracy: 0.7022 - val_loss: 0.5678 - val_accuracy: 0.7333
# Epoch 7/15
# 675/675 [==============================] - 0s 340us/step - loss: 0.5329 - accuracy: 0.7170 - val_loss: 0.5695 - val_accuracy: 0.7200
# Epoch 8/15
# 675/675 [==============================] - 0s 362us/step - loss: 0.4922 - accuracy: 0.7333 - val_loss: 0.5600 - val_accuracy: 0.6800
# Epoch 9/15
# 675/675 [==============================] - 0s 329us/step - loss: 0.4213 - accuracy: 0.8089 - val_loss: 0.6016 - val_accuracy: 0.7067
# Epoch 10/15
# 675/675 [==============================] - 0s 359us/step - loss: 0.3817 - accuracy: 0.8237 - val_loss: 0.6404 - val_accuracy: 0.6933
# Epoch 11/15
# 675/675 [==============================] - 0s 359us/step - loss: 0.3228 - accuracy: 0.8504 - val_loss: 0.6245 - val_accuracy: 0.6933
# Epoch 12/15
# 675/675 [==============================] - 0s 355us/step - loss: 0.2702 - accuracy: 0.8919 - val_loss: 0.6629 - val_accuracy: 0.7333
# Epoch 13/15
# 675/675 [==============================] - 0s 328us/step - loss: 0.2007 - accuracy: 0.9304 - val_loss: 0.7026 - val_accuracy: 0.7333
# Epoch 14/15
# 675/675 [==============================] - 0s 352us/step - loss: 0.1532 - accuracy: 0.9511 - val_loss: 0.8067 - val_accuracy: 0.7333
# Epoch 15/15
# 675/675 [==============================] - 0s 337us/step - loss: 0.1479 - accuracy: 0.9393 - val_loss: 0.8761 - val_accuracy: 0.7467
# accuracy: 61.6
# f1_socre:0.5958211091234348
# recall_socre:0.616
# precision_socre:0.5935706646294882

# %% [markdown]
# ### Enhanced LSTM

# %%
batch_size = 32
epochs = 5
validation_split = .1

e_lstm = dl.enhanced_lstm()

hist_e_lstm = e_lstm.fit([q1_train_padded, q2_train_padded], 
                   train['is_duplicate'], 
                   batch_size=batch_size, 
                   epochs=epochs, 
                   validation_split=validation_split)

pred_e_lstm = e_lstm.predict([q1_test_padded, q2_test_padded])

result_elstm = []
for i in pred_e_lstm:
    if i > .5:
        result_elstm.append(1)
    else:
        result_elstm.append(0)
        
count = 0
for i in range(len(result_elstm)):
    if result_elstm[i] == test['is_duplicate'].to_numpy()[i]:
        count = count +1

accuracy = (count/len(result_elstm))*100
print("accuracy: "  + str(accuracy))

print('f1_socre:' + str(f1_score(test['is_duplicate'], result_elstm, average = 'weighted')))
print('recall_socre:' + str(recall_score(test['is_duplicate'], result_elstm, average = 'weighted')))
print('precision_socre:' + str(precision_score(test['is_duplicate'], result_elstm, average = 'weighted')))

plot_model_training(hist_e_lstm)

#write_csv(result_elstm, test['id'], 'results/deep_learning/quora/elstm.csv')
# Out:
# Train on 675 samples, validate on 75 samples
# Epoch 1/5
# 675/675 [==============================] - 13s 19ms/step - loss: 0.9303 - accuracy: 0.5689 - val_loss: 0.6449 - val_accuracy: 0.6533
# Epoch 2/5
# 675/675 [==============================] - 9s 13ms/step - loss: 0.6354 - accuracy: 0.6726 - val_loss: 0.6802 - val_accuracy: 0.5733
# Epoch 3/5
# 675/675 [==============================] - 9s 13ms/step - loss: 0.5969 - accuracy: 0.7126 - val_loss: 0.6411 - val_accuracy: 0.6533
# Epoch 4/5
# 675/675 [==============================] - 9s 13ms/step - loss: 0.4513 - accuracy: 0.8000 - val_loss: 0.6427 - val_accuracy: 0.6400
# Epoch 5/5
# 675/675 [==============================] - 9s 13ms/step - loss: 0.3602 - accuracy: 0.8356 - val_loss: 0.6606 - val_accuracy: 0.6267
# accuracy: 62.8
# f1_socre:0.5048995692586716
# recall_socre:0.628
# precision_socre:0.582360655737705

# %% [markdown]
# # MSR Dataset: Preprocessing

# %%
# Loading the training and testing data
train = pd.read_csv(r'Data/msr_paraphrase_train.txt', sep = '\t', quoting=csv.QUOTE_NONE)
test = pd.read_csv(r'Data/msr_paraphrase_test.txt', sep = '\t', quoting=csv.QUOTE_NONE)

sent = list(train['#1 String']) + list(train['#2 String']) + list(test['#1 String']) + list(test['#2 String'])

#Creating the embedding matrix
NUM_WORDS = len(embeddings) #200000
tokenize = Tokenizer(num_words = NUM_WORDS)
tokenize.fit_on_texts(sent)
word_index = tokenize.word_index

sent1_train = tokenize.texts_to_sequences(train['#1 String'])
sent2_train = tokenize.texts_to_sequences(train['#2 String'])
sent1_test = tokenize.texts_to_sequences(test['#1 String'])
sent2_test = tokenize.texts_to_sequences(test['#2 String'])

max_seq_length = max_seq_len(sent1_train)
max_seq_length = max_seq_len(sent2_train, max_seq_length)
max_seq_length = max_seq_len(sent1_test, max_seq_length)
max_seq_length = max_seq_len(sent2_test, max_seq_length)

sent1_train_padded = pad_sequences(sent1_train, max_seq_length)
sent2_train_padded = pad_sequences(sent2_train, max_seq_length)
sent1_test_padded = pad_sequences(sent1_test, max_seq_length)
sent2_test_padded = pad_sequences(sent2_test, max_seq_length)
#Matrix with the embedding weights
embedding_dim = 300
embedding_weights = create_embedding_weights(embeddings, embedding_dim, word_index, NUM_WORDS)
NUM_WORDS = len(embedding_weights)
NUM_WORDS
# Out:
# 16539

# %% [markdown]
# ## Deep Learning Models

# %%
dl = deep_learning.deepModels(embedding_dim = embedding_dim,
                embedding_weights = embedding_weights,
                max_seq_length = max_seq_length,
                NUM_WORDS = NUM_WORDS)

# %% [markdown]
# ### Siamese LSTM

# %%
batch_size=32
epochs=15
validation_split=.1

lstm = dl.siamese_lstm(dropout_lstm=None)

hist_lstm = lstm.fit([sent1_train_padded, sent2_train_padded],
                     train['Quality'],
                     batch_size=batch_size, epochs=epochs, 
                     validation_split= validation_split)

pred_lstm = lstm.predict([sent1_test_padded, sent2_test_padded])

result_lstm = []
for i in pred_lstm:
    if i > .5:
        result_lstm.append(1)
    else:
        result_lstm.append(0)
        
count = 0
for i in range(len(result_lstm)):
    if result_lstm[i] == test['Quality'].to_numpy()[i]:
        count = count +1

accuracy = (count/len(result_lstm))*100
print('accuracy:'+ str(accuracy))

print('f1_socre:' + str(f1_score(test['Quality'], result_lstm, average = 'weighted')))
print('recall_socre:' + str(recall_score(test['Quality'], result_lstm, average = 'weighted')))
print('precision_socre:' + str(precision_score(test['Quality'], result_lstm, average = 'weighted')))

plot_model_training(hist_lstm)

#write_csv(result_lstm, test['id'], 'results/deep_learning/MSR/lstm.csv')
# Out:
# Train on 3668 samples, validate on 408 samples
# Epoch 1/15
# 3668/3668 [==============================] - 8s 2ms/step - loss: 0.6222 - accuracy: 0.6846 - val_loss: 0.6661 - val_accuracy: 0.6961
# Epoch 2/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.3790 - accuracy: 0.8479 - val_loss: 0.7911 - val_accuracy: 0.6961
# Epoch 3/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.2662 - accuracy: 0.9043 - val_loss: 0.6075 - val_accuracy: 0.7132
# Epoch 4/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.1950 - accuracy: 0.9297 - val_loss: 0.5827 - val_accuracy: 0.7181
# Epoch 5/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.1435 - accuracy: 0.9591 - val_loss: 0.6618 - val_accuracy: 0.7206
# Epoch 6/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.1093 - accuracy: 0.9695 - val_loss: 0.6982 - val_accuracy: 0.7230
# Epoch 7/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.0792 - accuracy: 0.9763 - val_loss: 0.6903 - val_accuracy: 0.7377
# Epoch 8/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.0492 - accuracy: 0.9872 - val_loss: 0.8521 - val_accuracy: 0.7010
# Epoch 9/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.0398 - accuracy: 0.9910 - val_loss: 0.8267 - val_accuracy: 0.7181
# Epoch 10/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.0196 - accuracy: 0.9978 - val_loss: 0.8565 - val_accuracy: 0.7623
# Epoch 11/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.0108 - accuracy: 0.9995 - val_loss: 0.8415 - val_accuracy: 0.7475
# Epoch 12/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.0103 - accuracy: 0.9989 - val_loss: 0.9133 - val_accuracy: 0.7206
# Epoch 13/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.0101 - accuracy: 0.9992 - val_loss: 0.9586 - val_accuracy: 0.7500
# Epoch 14/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.0084 - accuracy: 0.9989 - val_loss: 0.9345 - val_accuracy: 0.7475
# Epoch 15/15
# 3668/3668 [==============================] - 7s 2ms/step - loss: 0.0095 - accuracy: 0.9989 - val_loss: 1.0291 - val_accuracy: 0.7426
# accuracy:72.7536231884058
# f1_socre:0.7030441542918242
# recall_socre:0.7275362318840579
# precision_socre:0.7163876978265604

# %% [markdown]
# ### Siamese GRU

# %%
batch_size=100
epochs=15
validation_split=.1

gru = dl.Siamese_GRU()

hist_gru = gru.fit([sent1_train_padded, 
                    sent2_train_padded],
                   train['Quality'],
                   batch_size=batch_size,
                   epochs=epochs, 
                   validation_split=validation_split)

pred_gru = gru.predict([sent1_test_padded, sent2_test_padded])

result_gru = []
for i in pred_gru:
    if i > .5:
        result_gru.append(1)
    else:
        result_gru.append(0)
        
count = 0
for i in range(len(result_gru)):
    if result_gru[i] == test['Quality'].to_numpy()[i]:
        count = count +1

accuracy = (count/len(result_gru))*100
print('accuracy: ' + str(accuracy))

print('f1_socre:' + str(f1_score(test['Quality'], result_gru, average = 'weighted')))
print('recall_socre:' + str(recall_score(test['Quality'], result_gru, average = 'weighted')))
print('precision_socre:' + str(precision_score(test['Quality'], result_gru, average = 'weighted')))

plot_model_training(hist_gru)

#write_csv(result_gru, test['id'], 'results/deep_learning/MSR/GRU.csv')
# Out:
# Train on 3668 samples, validate on 408 samples
# Epoch 1/15
# 3668/3668 [==============================] - 5s 1ms/step - loss: 0.7326 - accuracy: 0.6292 - val_loss: 0.6292 - val_accuracy: 0.6961
# Epoch 2/15
# 3668/3668 [==============================] - 3s 935us/step - loss: 0.3403 - accuracy: 0.8738 - val_loss: 0.6344 - val_accuracy: 0.6961
# Epoch 3/15
# 3668/3668 [==============================] - 3s 935us/step - loss: 0.2628 - accuracy: 0.9117 - val_loss: 0.6515 - val_accuracy: 0.6985
# Epoch 4/15
# 3668/3668 [==============================] - 4s 986us/step - loss: 0.2213 - accuracy: 0.9321 - val_loss: 0.6693 - val_accuracy: 0.6936
# Epoch 5/15
# 3668/3668 [==============================] - 3s 949us/step - loss: 0.1963 - accuracy: 0.9392 - val_loss: 0.6881 - val_accuracy: 0.6912
# Epoch 6/15
# 3668/3668 [==============================] - 3s 944us/step - loss: 0.1747 - accuracy: 0.9438 - val_loss: 0.6990 - val_accuracy: 0.6985
# Epoch 7/15
# 3668/3668 [==============================] - 3s 942us/step - loss: 0.1570 - accuracy: 0.9520 - val_loss: 0.7395 - val_accuracy: 0.6936
# Epoch 8/15
# 3668/3668 [==============================] - 3s 921us/step - loss: 0.1317 - accuracy: 0.9605 - val_loss: 0.7889 - val_accuracy: 0.6912
# Epoch 9/15
# 3668/3668 [==============================] - 3s 948us/step - loss: 0.1153 - accuracy: 0.9651 - val_loss: 0.7817 - val_accuracy: 0.7059
# Epoch 10/15
# 3668/3668 [==============================] - 3s 935us/step - loss: 0.0927 - accuracy: 0.9755 - val_loss: 0.8154 - val_accuracy: 0.6912
# Epoch 11/15
# 3668/3668 [==============================] - 3s 927us/step - loss: 0.0847 - accuracy: 0.9782 - val_loss: 0.8426 - val_accuracy: 0.7034
# Epoch 12/15
# 3668/3668 [==============================] - 3s 932us/step - loss: 0.0650 - accuracy: 0.9828 - val_loss: 0.9077 - val_accuracy: 0.7157
# Epoch 13/15
# 3668/3668 [==============================] - 4s 958us/step - loss: 0.0529 - accuracy: 0.9869 - val_loss: 0.9002 - val_accuracy: 0.7034
# Epoch 14/15
# 3668/3668 [==============================] - 3s 924us/step - loss: 0.0494 - accuracy: 0.9872 - val_loss: 0.9479 - val_accuracy: 0.7010
# Epoch 15/15
# 3668/3668 [==============================] - 4s 956us/step - loss: 0.0297 - accuracy: 0.9940 - val_loss: 1.0222 - val_accuracy: 0.7083
# accuracy: 69.97101449275362
# f1_socre:0.6844248987830418
# recall_socre:0.6997101449275362
# precision_socre:0.68354389289636

# %% [markdown]
# ### Siamese CNN

# %%
batch_size = 100
epochs = 15
validation_split = 0.1


cnn = dl.siamese_cnn(filters= 16, kernel_size= 3)

hist_cnn = cnn.fit([sent1_train_padded, sent2_train_padded], 
                   train['Quality'], 
                   batch_size=batch_size, 
                   epochs=epochs, 
                   validation_split=validation_split)

pred_cnn = cnn.predict([sent1_test_padded, sent2_test_padded])

result_cnn = []
for i in pred_cnn:
    if i > .5:
        result_cnn.append(1)
    else:
        result_cnn.append(0)
        
count = 0
for i in range(len(result_cnn)):
    if result_cnn[i] == test['Quality'].to_numpy()[i]:
        count = count +1

accuracy = (count/len(result_cnn))*100
print("accuracy: " + str(accuracy))

print('f1_socre:' + str(f1_score(test['Quality'], result_cnn, average = 'weighted')))
print('recall_socre:' + str(recall_score(test['Quality'], result_cnn, average = 'weighted')))
print('precision_socre:' + str(precision_score(test['Quality'], result_cnn, average = 'weighted')))

plot_model_training(hist_cnn)

#write_csv(result_cnn, test['id'], 'results/deep_learning/MSR/CNN.csv')
# Out:
# Train on 3668 samples, validate on 408 samples
# Epoch 1/15
# 3668/3668 [==============================] - 1s 370us/step - loss: 0.6230 - accuracy: 0.6652 - val_loss: 0.5934 - val_accuracy: 0.6985
# Epoch 2/15
# 3668/3668 [==============================] - 0s 70us/step - loss: 0.5727 - accuracy: 0.6952 - val_loss: 0.6226 - val_accuracy: 0.6348
# Epoch 3/15
# 3668/3668 [==============================] - 0s 71us/step - loss: 0.5505 - accuracy: 0.7102 - val_loss: 0.5919 - val_accuracy: 0.7034
# Epoch 4/15
# 3668/3668 [==============================] - 0s 71us/step - loss: 0.5159 - accuracy: 0.7410 - val_loss: 0.5818 - val_accuracy: 0.7010
# Epoch 5/15
# 3668/3668 [==============================] - 0s 70us/step - loss: 0.4803 - accuracy: 0.7704 - val_loss: 0.5925 - val_accuracy: 0.6691
# Epoch 6/15
# 3668/3668 [==============================] - 0s 73us/step - loss: 0.4396 - accuracy: 0.8043 - val_loss: 0.5851 - val_accuracy: 0.6863
# Epoch 7/15
# 3668/3668 [==============================] - 0s 70us/step - loss: 0.4001 - accuracy: 0.8402 - val_loss: 0.5859 - val_accuracy: 0.6887
# Epoch 8/15
# 3668/3668 [==============================] - 0s 71us/step - loss: 0.3542 - accuracy: 0.8659 - val_loss: 0.6033 - val_accuracy: 0.6887
# Epoch 9/15
# 3668/3668 [==============================] - 0s 72us/step - loss: 0.3115 - accuracy: 0.8956 - val_loss: 0.6069 - val_accuracy: 0.7034
# Epoch 10/15
# 3668/3668 [==============================] - 0s 74us/step - loss: 0.2661 - accuracy: 0.9294 - val_loss: 0.6316 - val_accuracy: 0.6912
# Epoch 11/15
# 3668/3668 [==============================] - 0s 72us/step - loss: 0.2227 - accuracy: 0.9507 - val_loss: 0.6425 - val_accuracy: 0.6765
# Epoch 12/15
# 3668/3668 [==============================] - 0s 72us/step - loss: 0.1845 - accuracy: 0.9673 - val_loss: 0.6720 - val_accuracy: 0.6838
# Epoch 13/15
# 3668/3668 [==============================] - 0s 72us/step - loss: 0.1509 - accuracy: 0.9796 - val_loss: 0.7012 - val_accuracy: 0.7059
# Epoch 14/15
# 3668/3668 [==============================] - 0s 71us/step - loss: 0.1223 - accuracy: 0.9866 - val_loss: 0.7239 - val_accuracy: 0.6814
# Epoch 15/15
# 3668/3668 [==============================] - 0s 74us/step - loss: 0.0976 - accuracy: 0.9929 - val_loss: 0.7691 - val_accuracy: 0.6912
# accuracy: 67.71014492753623
# f1_socre:0.6602731288879298
# recall_socre:0.6771014492753623
# precision_socre:0.6574711003265467

# %% [markdown]
# ### Deep NN

# %%
batch_size = 100
epochs = 15
validation_split = 0.1

snli = dl.deep_nn()

hist_snli = snli.fit([sent1_train_padded, sent2_train_padded], 
                   train['Quality'], 
                   batch_size=batch_size, 
                   epochs=epochs, 
                   validation_split=validation_split)

pred_snli = snli.predict([sent1_test_padded, sent2_test_padded])

result_snli = []
for i in pred_snli:
    if i > .5:
        result_snli.append(1)
    else:
        result_snli.append(0)
        
count = 0
for i in range(len(result_snli)):
    if result_snli[i] == test['Quality'].to_numpy()[i]:
        count = count +1

accuracy = (count/len(result_snli))*100
print("accuracy: " + str(accuracy))

print('f1_socre:' + str(f1_score(test['Quality'], result_snli, average = 'weighted')))
print('recall_socre:' + str(recall_score(test['Quality'], result_snli, average = 'weighted')))
print('precision_socre:' + str(precision_score(test['Quality'], result_snli, average = 'weighted')))

plot_model_training(hist_snli)

#write_csv(result_snli, test['id'], 'results/deep_learning/MSR/Deep_NN.csv')
# Out:
# Train on 3668 samples, validate on 408 samples
# Epoch 1/15
# 3668/3668 [==============================] - 2s 413us/step - loss: 0.7575 - accuracy: 0.5774 - val_loss: 0.6153 - val_accuracy: 0.6961
# Epoch 2/15
# 3668/3668 [==============================] - 1s 137us/step - loss: 0.6755 - accuracy: 0.6300 - val_loss: 0.6134 - val_accuracy: 0.6961
# Epoch 3/15
# 3668/3668 [==============================] - 0s 134us/step - loss: 0.6515 - accuracy: 0.6570 - val_loss: 0.6366 - val_accuracy: 0.6961
# Epoch 4/15
# 3668/3668 [==============================] - 0s 131us/step - loss: 0.6304 - accuracy: 0.6660 - val_loss: 0.6100 - val_accuracy: 0.7010
# Epoch 5/15
# 3668/3668 [==============================] - 0s 134us/step - loss: 0.6045 - accuracy: 0.6892 - val_loss: 0.5931 - val_accuracy: 0.7132
# Epoch 6/15
# 3668/3668 [==============================] - 0s 133us/step - loss: 0.5728 - accuracy: 0.7088 - val_loss: 0.7202 - val_accuracy: 0.4902
# Epoch 7/15
# 3668/3668 [==============================] - 1s 138us/step - loss: 0.5238 - accuracy: 0.7377 - val_loss: 0.5782 - val_accuracy: 0.7108
# Epoch 8/15
# 3668/3668 [==============================] - 0s 134us/step - loss: 0.4573 - accuracy: 0.7814 - val_loss: 0.6559 - val_accuracy: 0.6152
# Epoch 9/15
# 3668/3668 [==============================] - 0s 135us/step - loss: 0.4008 - accuracy: 0.8141 - val_loss: 0.6278 - val_accuracy: 0.6961
# Epoch 10/15
# 3668/3668 [==============================] - 0s 133us/step - loss: 0.3379 - accuracy: 0.8501 - val_loss: 0.9639 - val_accuracy: 0.4951
# Epoch 11/15
# 3668/3668 [==============================] - 0s 134us/step - loss: 0.2678 - accuracy: 0.8934 - val_loss: 1.9591 - val_accuracy: 0.3260
# Epoch 12/15
# 3668/3668 [==============================] - 0s 136us/step - loss: 0.2205 - accuracy: 0.9111 - val_loss: 1.4450 - val_accuracy: 0.4559
# Epoch 13/15
# 3668/3668 [==============================] - 1s 138us/step - loss: 0.1571 - accuracy: 0.9422 - val_loss: 1.3336 - val_accuracy: 0.5711
# Epoch 14/15
# 3668/3668 [==============================] - 0s 134us/step - loss: 0.1434 - accuracy: 0.9447 - val_loss: 2.2482 - val_accuracy: 0.3824
# Epoch 15/15
# 3668/3668 [==============================] - 1s 138us/step - loss: 0.1550 - accuracy: 0.9387 - val_loss: 1.0502 - val_accuracy: 0.5956
# accuracy: 57.507246376811594
# f1_socre:0.5868401799804847
# recall_socre:0.5750724637681159
# precision_socre:0.621456829161177

# %% [markdown]
# ### Hybrid CNN-LSTM

# %%
batch_size = 100
epochs = 15
validation_split = 0.1

hybrid = dl.hybrid_model()

hist_hybrid = hybrid.fit([sent1_train_padded, sent2_train_padded], 
                   train['Quality'], 
                   batch_size=batch_size, 
                   epochs=epochs, 
                   validation_split=validation_split)

pred_hybrid = hybrid.predict([sent1_test_padded, sent2_test_padded])

result_hybrid = []
for i in pred_hybrid:
    if i > .5:
        result_hybrid.append(1)
    else:
        result_hybrid.append(0)
        
count = 0
for i in range(len(result_hybrid)):
    if result_hybrid[i] == test['Quality'].to_numpy()[i]:
        count = count +1

accuracy = (count/len(result_hybrid))*100
print('accuracy: '+ str(accuracy))


print('f1_socre:' + str(f1_score(test['Quality'], result_hybrid, average = 'weighted')))
print('recall_socre:' + str(recall_score(test['Quality'], result_hybrid, average = 'weighted')))
print('precision_socre:' + str(precision_score(test['Quality'], result_hybrid, average = 'weighted')))

plot_model_training(hist_hybrid)

#write_csv(result_hybrid, test['id'], 'results/deep_learning/MSR/hybrid.csv')
# Out:
# Train on 3668 samples, validate on 408 samples
# Epoch 1/15
# 3668/3668 [==============================] - 3s 777us/step - loss: 0.6892 - accuracy: 0.6442 - val_loss: 0.6024 - val_accuracy: 0.6961
# Epoch 2/15
# 3668/3668 [==============================] - 1s 163us/step - loss: 0.6127 - accuracy: 0.6731 - val_loss: 0.5840 - val_accuracy: 0.6961
# Epoch 3/15
# 3668/3668 [==============================] - 1s 163us/step - loss: 0.5960 - accuracy: 0.6696 - val_loss: 0.5791 - val_accuracy: 0.7010
# Epoch 4/15
# 3668/3668 [==============================] - 1s 164us/step - loss: 0.5753 - accuracy: 0.6816 - val_loss: 0.5824 - val_accuracy: 0.6985
# Epoch 5/15
# 3668/3668 [==============================] - 1s 169us/step - loss: 0.5505 - accuracy: 0.6897 - val_loss: 0.5901 - val_accuracy: 0.7083
# Epoch 6/15
# 3668/3668 [==============================] - 1s 169us/step - loss: 0.5110 - accuracy: 0.7203 - val_loss: 0.6140 - val_accuracy: 0.6397
# Epoch 7/15
# 3668/3668 [==============================] - 1s 168us/step - loss: 0.4687 - accuracy: 0.7587 - val_loss: 0.6942 - val_accuracy: 0.7157
# Epoch 8/15
# 3668/3668 [==============================] - 1s 165us/step - loss: 0.4178 - accuracy: 0.7909 - val_loss: 0.6786 - val_accuracy: 0.6593 - loss: 0.4156 - accuracy: 0.79
# Epoch 9/15
# 3668/3668 [==============================] - 1s 163us/step - loss: 0.3733 - accuracy: 0.8053 - val_loss: 0.7554 - val_accuracy: 0.6765
# Epoch 10/15
# 3668/3668 [==============================] - 1s 169us/step - loss: 0.3395 - accuracy: 0.8389 - val_loss: 0.8585 - val_accuracy: 0.6887
# Epoch 11/15
# 3668/3668 [==============================] - 1s 160us/step - loss: 0.3137 - accuracy: 0.8441 - val_loss: 0.8753 - val_accuracy: 0.6740
# Epoch 12/15
# 3668/3668 [==============================] - 1s 162us/step - loss: 0.2896 - accuracy: 0.8593 - val_loss: 0.9565 - val_accuracy: 0.6544
# Epoch 13/15
# 3668/3668 [==============================] - 1s 167us/step - loss: 0.2804 - accuracy: 0.8612 - val_loss: 1.0224 - val_accuracy: 0.6642
# Epoch 14/15
# 3668/3668 [==============================] - 1s 166us/step - loss: 0.2620 - accuracy: 0.8702 - val_loss: 1.0228 - val_accuracy: 0.6814
# Epoch 15/15
# 3668/3668 [==============================] - 1s 163us/step - loss: 0.2502 - accuracy: 0.8779 - val_loss: 1.0172 - val_accuracy: 0.6225
# accuracy: 63.36231884057971
# f1_socre:0.6134729002167567
# recall_socre:0.6336231884057971
# precision_socre:0.606604375170905

# %% [markdown]
# ### Enhanced LSTM

# %%
batch_size = 100
epochs = 15
validation_split = 0.1

e_lstm = dl.enhanced_lstm()

hist_e_lstm = e_lstm.fit([sent1_train_padded, sent2_train_padded], 
                   train['Quality'], 
                   batch_size=batch_size, 
                   epochs=epochs, 
                   validation_split=validation_split)

pred_e_lstm = e_lstm.predict([sent1_test_padded, sent2_test_padded])

result_e_lstm = []
for i in pred_e_lstm:
    if i > .5:
        result_e_lstm.append(1)
    else:
        result_e_lstm.append(0)
        
count = 0
for i in range(len(result_e_lstm)):
    if result_e_lstm[i] == test['Quality'].to_numpy()[i]:
        count = count +1

accuracy = (count/len(result_e_lstm))*100
print("accuracy: " + str(accuracy))

print('f1_socre:' + str(f1_score(test['Quality'], result_e_lstm, average = 'weighted')))
print('recall_socre:' + str(recall_score(test['Quality'], result_e_lstm, average = 'weighted')))
print('precision_socre:' + str(precision_score(test['Quality'], result_e_lstm, average = 'weighted')))

plot_model_training(hist_e_lstm)

#write_csv(result_elstm, test['id'], 'results/deep_learning/MSR/elstm.csv')
# Out:
# Train on 3668 samples, validate on 408 samples
# Epoch 1/15
# 3668/3668 [==============================] - 24s 7ms/step - loss: 0.8032 - accuracy: 0.6292 - val_loss: 0.6319 - val_accuracy: 0.6961
# Epoch 2/15
# 3668/3668 [==============================] - 20s 6ms/step - loss: 0.5462 - accuracy: 0.7410 - val_loss: 0.5884 - val_accuracy: 0.6961
# Epoch 3/15
# 3668/3668 [==============================] - 21s 6ms/step - loss: 0.5059 - accuracy: 0.7672 - val_loss: 0.6595 - val_accuracy: 0.6961
# Epoch 4/15
# 3668/3668 [==============================] - 22s 6ms/step - loss: 0.4185 - accuracy: 0.8165 - val_loss: 0.7946 - val_accuracy: 0.6961
# Epoch 5/15
# 3668/3668 [==============================] - 22s 6ms/step - loss: 0.3375 - accuracy: 0.8555 - val_loss: 0.7748 - val_accuracy: 0.6912
# Epoch 6/15
# 3668/3668 [==============================] - 22s 6ms/step - loss: 0.2416 - accuracy: 0.9054 - val_loss: 0.9293 - val_accuracy: 0.6985
# Epoch 7/15
# 3668/3668 [==============================] - 22s 6ms/step - loss: 0.1777 - accuracy: 0.9318 - val_loss: 1.0523 - val_accuracy: 0.6961
# Epoch 8/15
# 3668/3668 [==============================] - 22s 6ms/step - loss: 0.1221 - accuracy: 0.9558 - val_loss: 0.9132 - val_accuracy: 0.7157
# Epoch 9/15
# 3668/3668 [==============================] - 20s 6ms/step - loss: 0.0784 - accuracy: 0.9695 - val_loss: 1.1251 - val_accuracy: 0.7083
# Epoch 10/15
# 3668/3668 [==============================] - 20s 6ms/step - loss: 0.0859 - accuracy: 0.9673 - val_loss: 1.5487 - val_accuracy: 0.6961
# Epoch 11/15
# 3668/3668 [==============================] - 21s 6ms/step - loss: 0.0569 - accuracy: 0.9798 - val_loss: 1.2062 - val_accuracy: 0.7206
# Epoch 12/15
# 3668/3668 [==============================] - 23s 6ms/step - loss: 0.0470 - accuracy: 0.9845 - val_loss: 1.3257 - val_accuracy: 0.7328
# Epoch 13/15
# 3668/3668 [==============================] - 22s 6ms/step - loss: 0.0427 - accuracy: 0.9850 - val_loss: 1.1478 - val_accuracy: 0.7525
# Epoch 14/15
# 3668/3668 [==============================] - 22s 6ms/step - loss: 0.0365 - accuracy: 0.9877 - val_loss: 1.0132 - val_accuracy: 0.7525
# Epoch 15/15
# 3668/3668 [==============================] - 22s 6ms/step - loss: 0.0449 - accuracy: 0.9842 - val_loss: 1.3400 - val_accuracy: 0.7034
# accuracy: 71.07246376811595
# f1_socre:0.6963479358024639
# recall_socre:0.7107246376811595
# precision_socre:0.6962515480876463
